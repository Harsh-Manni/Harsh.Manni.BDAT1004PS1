# %% [markdown]
# # BDAT1004- Problem Set 1

# %% [markdown]
# # Question 1
#
# What data type is each of the following?

# %% [markdown]
# |Problem            | Data Type                                                                              |
# | :---              |-----------------:                                                                      |
# | 5                 | int                                                                                    |
# | 5.0               | double                                                                                 |
# | 5>1               | Boolean                                                                                |
# | '5'               | int                                                                                    |
# | 5 * 2             | int                                                                                    |
# | '5' * 2           | int                                                                                    |
# | '5' + '2'         | int                                                                                    |
# | 5 / 2             | Float/double/decimal                                                                   |
# | 5 % 2             | int                                                                                    |
# | {5,2,1}           | Array of integers                                                                      |
# | 5==3              | Boolean                                                                                |
# | pi (the number)   | double                                                                                 |

# %% [markdown]
# # Question 2a
# How many letters are there in 'Supercalifragilisticexpialidocious'?

# %% [markdown]
# using System;
#
# public class StringName
# {
#     public static void Main()
#     {
#         string str;
#         int alphabet, digit, specialchar, i, l;
#         alphabet = digit = specialchar = i = 0;
#         Console.Write("Enter the String");
#         str = Console.ReadLine();
#         l = str.Length;
#         while (i < l)
#         {
#             if ((str[i] >= 'a' && str[i] <= 'z') || (str[i] >= 'A' && str[i] <= 'Z'))
#             {
#                 alphabet++;
#             }
#             else if (str[i] >= '0' && str[i] <= '9')
#             {
#                 digit++;
#             }
#             else
#             {
#                 specialchar++;
#             }
#             i++;
#         }
#         Console.Write("number of Alphabets in string is :{0}\n", alphabet);
#         Console.Write("number of Digits in string is :{0}\n", digit);
#         Console.Write("number of Specialchar in string is :{0}\n", specialchar);
#         Console.ReadLine();
#     }
#     }

# %% [markdown]
# ![2021-09-30.png](attachment:2021-09-30.png)

# %% [markdown]
# # Question 2b
# Does 'Supercalifragilisticexpialidocious' contain 'ice' as a substring?

# %% [markdown]
# using System;
# public class Extract
# {
#     public static void Main()
#     {
#         String str = "Supercalifragilisticexpialidocious";
#         String str1 = "ice";
#         if (str.Contains(str1))
#         {
#             Console.WriteLine(true);
#         }
#         else
#         {
#             Console.WriteLine(false);
#         }
#     }
# }

# %% [markdown]
# ![2021-09-30%20%281%29.png](attachment:2021-09-30%20%281%29.png)

# %% [markdown]
# # Question 2c
# Which of the following words is the longest:
# Supercalifragilisticexpialidocious, Honorificabilitudinitatibus, or
# Bababadalgharaghtakamminarronnkonn?

# %% [markdown]
# using System;
# public class program
# {
#     public static void Main()
#     {
#         String text;
#         String[]stringList;
#         int ni=0,L,max=0;
#         Console.Write("enter a string:");
#         text = Console.ReadLine();
#         stringList = text.Split(' ');
#         l = stringList.Length;
#         for(int i = 0; i < L; i++)
#         {
#             if (stringList[i].Length > max)
#             {
#                 max = stringList[i].Length;
#                 ni = i;
#             }
#         }
#         Console.WriteLine("Longest string:{0}\nCount of Character:{1}",stringList[ni],max);
#         Console.ReadLine();
#     }
# }

# %% [markdown]
# ![longest.png](attachment:longest.png)

# %% [markdown]
# # question 3
# Implement function triangleArea(a,b,c) that takes as input the lengths of the 3
# sides of a triangle and returns the area of the triangle. By Heron's formula, the area
# of a triangle with side lengths a, b, and c is
# s(s - a)(s -b)(s -c)
# , where
# s = (a+b+c)/2.
# >>> triangleArea(2,2,2)
# 1.7320508075688772

# %% [markdown]
# using System;
#
# namespace std
# {
#     public class program
#     {
#         public static void Main(string[] args)
#         {
#             double s, area, a, b, c;
#             Console.WriteLine("Enter Length of side 1:");
#             a = double.Parse(Console.ReadLine());
#             Console.WriteLine("Enter Length of side 2:");
#             b = double.Parse(Console.ReadLine());
#             Console.WriteLine("Enter Length of side 3:");
#             c = double.Parse(Console.ReadLine());
#             s = (a + b + c) / 2;
#             area = Math.Sqrt(s * (s - a) * (s - b) * (s - c));        //StackOverflow.com
#             Console.WriteLine("Area = {0}", area);
#         }
#         }
#     }

# %% [markdown]
# ![triarea.png](attachment:triarea.png)

# %% [markdown]
# # Question 5
# Write a function inside(x,y,x1,y1,x2,y2) that returns True or False
# depending on whether the point (x,y) lies in the rectangle with lower left
# corner (x1,y1) and upper right corner (x2,y2).
# >>> inside(1,1,0,0,2,3)
# True
# >>> inside(-1,-1,0,0,2,3)
# False

# %% [markdown]
# using System;
#
# class std
# {
#     static bool inside(double x, double y, double x1, double y1, double x2, double y2)
#     {
#         if (x > x1 && x < x2 && y > y1 && y < y2)
#
#             return true;
#         return false;
#     }
#     public static void Main()
#     {
#         double x1 = 0.3, y1 = 0.5;
#         double x2 = 1.1, y2 = 0.7;
#         double x = 1, y = 1;
#         if (inside(x1, y1, x2, y2, x, y))
#             Console.Write("yes");
#         else
#             Console.Write("NO");
#     }
# }

# %% [markdown]
# # question 6
# You can turn a word into pig-Latin using the following two rules (simplified):
# • If the word starts with a consonant, move that letter to the end and append
# 'ay'. For example, 'happy' becomes 'appyhay' and 'pencil' becomes 'encilpay'.
# • If the word starts with a vowel, simply append 'way' to the end of the word.
# For example, 'enter' becomes 'enterway' and 'other' becomes 'otherway' . For
# our purposes, there are 5 vowels: a, e, i, o, u (so we count y as a consonant).
# Write a function pig() that takes a word (i.e., a string) as input and returns its pigLatin form. Your function should still work if the input word contains upper case
# characters. Your output should always be lower case however.
# >>> pig('happy')
# 'appyhay'
# >>> pig('Enter')
# 'enterway'

# %%
pigLatin=input("Convert message to pig latin:")
wordList=pigLatin.lower().split(" ")
vowels=['a','e','i','o','u']
pigLatin=[]
eachWord=[]
for word in wordList:
    if word[0]in 'aeiou':             # For words starting vowels
        pigLatin.append(word+'way')
    else:
            for letter in word:       # For words starting with consonant
                if letter in 'aeiou':
                    pigLatin.append(word[word.index(letter):]+word[:word.index(letter)]+'ay')
                    break
print(" ".join(pigLatin))
# Out:
# Convert message to pig latin:happy
# appyhay

# %%
pigLatin=input("Convert message to pig latin:")
wordList=pigLatin.lower().split(" ")
vowels=['a','e','i','o','u']
pigLatin=[]
eachWord=[]
for word in wordList:
    if word[0]in 'aeiou':             # For words starting vowels
        pigLatin.append(word+'way')
    else:
            for letter in word:       # For words starting with consonant
                if letter in 'aeiou':
                    pigLatin.append(word[word.index(letter):]+word[:word.index(letter)]+'ay')
                    break
print(" ".join(pigLatin))
# Out:
# Convert message to pig latin:enter
# enterway

# %% [markdown]
# # question 8
# Write a function curconv() that takes as input:
# 1. a currency represented using a string (e.g., 'JPY' for the Japanese Yen or
# 'EUR' for the Euro)
# 2. an amount
# and then converts and returns the amount in US dollars.
# >>> curconv('EUR', 100)
# 122.96544
# >>> curconv('JPY', 100)
# 1.241401

# %%
with open('OneDrive/Desktop/currencies.txt')as f:  
    lines=f.readlines()
    curconv={}
    for line in lines:
        parsed=line.split("\t")
        curconv[parsed[0]]=parsed[1]
        
    amount=int(input("Enter amount:\n"))
    print("Enter the name of the currency you want to convert to.\n Available:\n")
    [print(item)for item in curconv.keys()]
    currency=input("Please enter one of these values:\n")
    print(f"{amount}US Dollars amounts to {amount*float(curconv[currency])}{currency}")
# Out:
# Enter amount:
# 100
# Enter the name of the currency you want to convert to.
#  Available:
#
# AUD
# CHF
# CNY
# DKK
# EUR
# GBP
# HKD
# INR
# JPY
# MXN
# MYR
# NOK
# NZD
# PHP
# SEK
# SGD
# THB
# Please enter one of these values:
# EUR
# 100US Dollars amounts to 122.96544EUR

# %%
with open('OneDrive/Desktop/currencies.txt')as f:  
    lines=f.readlines()
    curconv={}
    for line in lines:
        parsed=line.split("\t")
        curconv[parsed[0]]=parsed[1]
        
    amount=int(input("Enter amount:\n"))
    print("Enter the name of the currency you want to convert to.\n Available:\n")
    [print(item)for item in curconv.keys()]
    currency=input("Please enter one of these values:\n")
    print(f"{amount}US Dollars amounts to {amount*float(curconv[currency])}{currency}")
# Out:
# Enter amount:
# 100
# Enter the name of the currency you want to convert to.
#  Available:
#
# AUD
# CHF
# CNY
# DKK
# EUR
# GBP
# HKD
# INR
# JPY
# MXN
# MYR
# NOK
# NZD
# PHP
# SEK
# SGD
# THB
# Please enter one of these values:
# JPY
# 100US Dollars amounts to 1.241401JPY
